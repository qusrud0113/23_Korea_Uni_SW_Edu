# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import declarative_base, sessionmaker, relationship
from sqlalchemy.schema import Table, Column, ForeignKey
from sqlalchemy.types import Integer, Text
from sqlalchemy.sql import select, insert, update, delete, join, func
import sqlalchemy

# %%
# reset
sess.rollback()
sess.close()
engine.dispose()
base.metadata.clear()
base.registry.dispose()
# Out:
# 2023-09-08 07:19:32,534 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# base
engine = create_engine('sqlite:///:memory:', echo = True)
base = declarative_base()
Session = sessionmaker(engine)
sess= Session()

# %%
"""
- 23.09.07 과제 - 

ORM을 이용하여 SNS의 게시글 추가/수정/삭제 에 대한 로직을 완성하시오

"""

# Artist 1:N Ablums (관계)
# Post N:M HashTag => 관계를 정의하고 있는 별도의 테이블을 써야함.
# Post               Tags              Hashtag
# tags-------------post/hashtag----------posts
# Posts.tags[0].hashtag -------------> Hashtag

class Post(base):
    __tablename__ = 'POST'
    __table_args__ = {'extend_existing': True}
    pk = Column('PK', Integer, primary_key= True)
    content = Column('CONTENT', Text)
    # tags는 Tags라는 Table과 관계를 갖고 있고, post를 통해 연결됨
    tags = relationship('Tags', back_populates='post', uselist=True)

    # tag 추가
    def addTags(self, tags):
        """
        IDEA) Tag 추가 함수:
        로직은 tag를 반복시켜서 Hashtag Table에 name과 매칭이 되면
        값을 추가하고, 매칭 값이 없으면 Tag를 추가한다.

        이후 추가된 Tag의 cnt값을 하나 증가시킨다.
        """
        tagList = []
        for tag in tags:
            rst = sess.query(Hashtag).filter(Hashtag.name == tag)
            if rst.count() > 0:
                tagList.append(rst.one())
            else:
                newTag = Hashtag(name = tag)
                sess.add(newTag)
                sess.commit()
                tagList.append(newTag)
        for tag in tagList:
            sess.add(Tags(fk1 = self.pk, fk2 = tag.pk))
            sess.commit()
            tag.cnt += 1

    # tag 삭제    
    def deleteTags(self, tags):
        """
        IDEA) Tag 삭제 함수:
        로직은 특정한 pk를 갖는 tag를 찾아서 (filter? or macthing?)
        삭제한다. (tag가 포함된 모든 post를 삭제하면 안되고, 글을 특정하는 pk와 태그를 매칭 시킨 후
        해당 row를 삭제한다) 이후 삭제된 Tag의 cnt값을 하나 감소시킨다.
        """        
        del_tagList = []
        for tag in tags:
            rst = sess.query(Hashtag).filter(Hashtag.name == tag)
            if rst.count() == 0:
                continue
            else:
                # 삭제할 tag를 뽑는다.
                deltag = sess.query(Hashtag).filter(Hashtag.name == tag).one()          
                sess.commit()
                del_tagList.append(deltag)
        for tag in del_tagList:
            # 삭제할 태그의 pk값 (Tags와 Hashtags의 상속관계를 사용해서 M:M 테이블을 매칭 시키는 테이블의 인자 삭제)
            sess.query(Tags).filter(Tags.fk1 == self.pk, Tags.fk2 == tag.pk).delete()
            sess.commit()
            # 삭제된 태그의 값을 하나 줄임.
            tag.cnt -= 1

    # tag 수정    
    def modifiedTags(self, tag1, tag2):
        """
        IDEA) Tag 수정 함수: 
        바꾸고자 하는 post의 pk와 Tag를 매칭 시킨 후 (pk = my.pk, Tag = my.tag),
        Tag의 값을 바꾼다. (Tag = '어쩌구', sess.commit())
        특정 Tag가 하나 사라지고, 특정 Tag가 하나 증가하였으므로
        추가된 Tag는 cnt +=1, 사라진 Tag는 cnt -=1을 취한다. (+-= 0)
        > 그냥 기존에 만들어둔 deleteTag와 addTag를 사용한다.

        tag1: 수정 전 태그
        tag2: 수정 후 태그
        """        
        self.deleteTags(tag1)
        self.addTags(tag2)
        

    def __repr__(self):
        return f'{self.pk}, {len(self.tags)}'
    
class Hashtag(base):
    __tablename__ = 'HASHTAG'
    __table_args__ = {'extend_existing': True}
    pk = Column('PK', Integer, primary_key= True)
    name = Column('NAME', Text)
    cnt = Column('CNT', Integer, server_default='0')
    posts = relationship('Tags', back_populates='hashtag', uselist=True)

    def __repr__(self):
        return f'{self.pk}, {self.name}, {len(self.posts)}'    

class Tags(base):
    __tablename__ = 'TAGS'
    __table_args__ = {'extend_existing': True}
    pk = Column('PK', Integer, primary_key= True)
    fk1 = Column('FK1', Integer, None, ForeignKey('POST.PK'))
    fk2 = Column('FK2', Integer, None, ForeignKey('HASHTAG.PK'))
    post = relationship('Post', back_populates='tags')
    hashtag = relationship('Hashtag', back_populates='posts')

# %%
# engine에 반영
base.metadata.create_all(engine)
# Out:
# 2023-09-08 07:19:39,399 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:39,400 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("POST")
# 2023-09-08 07:19:39,401 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,402 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("POST")
# 2023-09-08 07:19:39,402 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,404 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("HASHTAG")
# 2023-09-08 07:19:39,404 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,406 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("HASHTAG")
# 2023-09-08 07:19:39,408 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,410 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("TAGS")
# 2023-09-08 07:19:39,410 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,411 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("TAGS")
# 2023-09-08 07:19:39,412 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-08 07:19:39,412 INFO sqlalchemy.engine.Engine
# CREATE TABLE "POST" (
# 	"PK" INTEGER NOT NULL,
# 	"CONTENT" TEXT,
# 	PRIMARY KEY ("PK")
# )
#
#
# 2023-09-08 07:19:39,413 INFO sqlalchemy.engine.Engine [no key 0.00067s] ()
# 2023-09-08 07:19:39,414 INFO sqlalchemy.engine.Engine
# CREATE TABLE "HASHTAG" (
# 	"PK" INTEGER NOT NULL,
# 	"NAME" TEXT,
# 	"CNT" INTEGER DEFAULT '0',
# 	PRIMARY KEY ("PK")
# )
#
#
# 2023-09-08 07:19:39,415 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2023-09-08 07:19:39,416 INFO sqlalchemy.engine.Engine
# CREATE TABLE "TAGS" (
# 	"PK" INTEGER NOT NULL,
# 	"FK1" INTEGER,
# 	"FK2" INTEGER,
# 	PRIMARY KEY ("PK"),
# 	FOREIGN KEY("FK1") REFERENCES "POST" ("PK"),
# 	FOREIGN KEY("FK2") REFERENCES "HASHTAG" ("PK")
# )
#
#
# 2023-09-08 07:19:39,417 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2023-09-08 07:19:39,418 INFO sqlalchemy.engine.Engine COMMIT

# %%
# 테그 추가 예시
post1 = Post(content = '내용1')
sess.add(post1)
post2 = Post(content = '내용2')
sess.add(post2)
sess.commit()

tag1 = ['해시태그1', '해시태그2']
post1.addTags(tag1)

tag2 = ['해시태그1', '해시태그3']
post2.addTags(tag2)

sess.commit()
# Out:
# 2023-09-08 07:19:41,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,013 INFO sqlalchemy.engine.Engine INSERT INTO "POST" ("CONTENT") VALUES (?) RETURNING "PK"
# 2023-09-08 07:19:41,014 INFO sqlalchemy.engine.Engine [generated in 0.00009s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('내용1',)
# 2023-09-08 07:19:41,014 INFO sqlalchemy.engine.Engine INSERT INTO "POST" ("CONTENT") VALUES (?) RETURNING "PK"
# 2023-09-08 07:19:41,015 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('내용2',)
# 2023-09-08 07:19:41,017 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,020 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,022 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:41,023 INFO sqlalchemy.engine.Engine [generated in 0.00091s] ('해시태그1',)
# 2023-09-08 07:19:41,025 INFO sqlalchemy.engine.Engine INSERT INTO "HASHTAG" ("NAME") VALUES (?) RETURNING "PK", "CNT"
# 2023-09-08 07:19:41,026 INFO sqlalchemy.engine.Engine [generated in 0.00064s] ('해시태그1',)
# 2023-09-08 07:19:41,027 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,029 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,030 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:41,030 INFO sqlalchemy.engine.Engine [cached since 0.00836s ago] ('해시태그2',)
# 2023-09-08 07:19:41,032 INFO sqlalchemy.engine.Engine INSERT INTO "HASHTAG" ("NAME") VALUES (?) RETURNING "PK", "CNT"
# 2023-09-08 07:19:41,033 INFO sqlalchemy.engine.Engine [cached since 0.007645s ago] ('해시태그2',)
# 2023-09-08 07:19:41,034 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,035 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,037 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:41,038 INFO sqlalchemy.engine.Engine [generated in 0.00143s] (1,)
# 2023-09-08 07:19:41,040 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,041 INFO sqlalchemy.engine.Engine [generated in 0.00071s] (1,)
# 2023-09-08 07:19:41,043 INFO sqlalchemy.engine.Engine INSERT INTO "TAGS" ("FK1", "FK2") VALUES (?, ?)
# 2023-09-08 07:19:41,044 INFO sqlalchemy.engine.Engine [generated in 0.00068s] (1, 1)
# 2023-09-08 07:19:41,045 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,046 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,047 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,047 INFO sqlalchemy.engine.Engine [cached since 0.007319s ago] (1,)
# 2023-09-08 07:19:41,050 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,051 INFO sqlalchemy.engine.Engine [generated in 0.00146s] (1, 1)
# 2023-09-08 07:19:41,054 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:41,055 INFO sqlalchemy.engine.Engine [cached since 0.0183s ago] (1,)
# 2023-09-08 07:19:41,057 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,058 INFO sqlalchemy.engine.Engine [cached since 0.01841s ago] (2,)
# 2023-09-08 07:19:41,060 INFO sqlalchemy.engine.Engine INSERT INTO "TAGS" ("FK1", "FK2") VALUES (?, ?)
# 2023-09-08 07:19:41,062 INFO sqlalchemy.engine.Engine [cached since 0.01901s ago] (1, 2)
# 2023-09-08 07:19:41,064 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,067 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,069 INFO sqlalchemy.engine.Engine [cached since 0.02862s ago] (2,)
# 2023-09-08 07:19:41,072 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,073 INFO sqlalchemy.engine.Engine [cached since 0.02313s ago] (1, 2)
# 2023-09-08 07:19:41,075 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:41,076 INFO sqlalchemy.engine.Engine [cached since 0.05421s ago] ('해시태그1',)
# 2023-09-08 07:19:41,078 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?
# 2023-09-08 07:19:41,080 INFO sqlalchemy.engine.Engine [generated in 0.00150s] ('해시태그1',)
# 2023-09-08 07:19:41,082 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:41,084 INFO sqlalchemy.engine.Engine [cached since 0.06176s ago] ('해시태그3',)
# 2023-09-08 07:19:41,086 INFO sqlalchemy.engine.Engine INSERT INTO "HASHTAG" ("NAME") VALUES (?) RETURNING "PK", "CNT"
# 2023-09-08 07:19:41,088 INFO sqlalchemy.engine.Engine [cached since 0.06236s ago] ('해시태그3',)
# 2023-09-08 07:19:41,089 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,091 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,092 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:41,093 INFO sqlalchemy.engine.Engine [cached since 0.05579s ago] (2,)
# 2023-09-08 07:19:41,094 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,095 INFO sqlalchemy.engine.Engine [cached since 0.05525s ago] (1,)
# 2023-09-08 07:19:41,098 INFO sqlalchemy.engine.Engine INSERT INTO "TAGS" ("FK1", "FK2") VALUES (?, ?)
# 2023-09-08 07:19:41,100 INFO sqlalchemy.engine.Engine [cached since 0.05651s ago] (2, 1)
# 2023-09-08 07:19:41,101 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,104 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,104 INFO sqlalchemy.engine.Engine [cached since 0.06453s ago] (1,)
# 2023-09-08 07:19:41,106 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,107 INFO sqlalchemy.engine.Engine [cached since 0.05692s ago] (2, 1)
# 2023-09-08 07:19:41,108 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:41,108 INFO sqlalchemy.engine.Engine [cached since 0.07125s ago] (2,)
# 2023-09-08 07:19:41,109 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,109 INFO sqlalchemy.engine.Engine [cached since 0.06923s ago] (3,)
# 2023-09-08 07:19:41,110 INFO sqlalchemy.engine.Engine INSERT INTO "TAGS" ("FK1", "FK2") VALUES (?, ?)
# 2023-09-08 07:19:41,110 INFO sqlalchemy.engine.Engine [cached since 0.06739s ago] (2, 3)
# 2023-09-08 07:19:41,111 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:41,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:41,112 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,113 INFO sqlalchemy.engine.Engine [cached since 0.0727s ago] (3,)
# 2023-09-08 07:19:41,114 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:41,114 INFO sqlalchemy.engine.Engine [cached since 0.06408s ago] (1, 3)
# 2023-09-08 07:19:41,115 INFO sqlalchemy.engine.Engine COMMIT

# %%
# 확인
sess.query(Hashtag).all()
"""
pk     hashtag    cnt
1     해시태그1     2
2     해시태그2     1
3     해시태그3     1
"""
# Out:
# 2023-09-08 07:19:43,045 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:43,045 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# 2023-09-08 07:19:43,060 INFO sqlalchemy.engine.Engine [generated in 0.00075s] ()
# '\npk     hashtag    cnt\n1     해시태그1     2\n2     해시태그2     1\n3     해시태그3     1\n'

# %%
# 테그 제거 예시
de1_tag1 = ['해시태그1']
post1.deleteTags(de1_tag1)
sess.commit()

de1_tag2 = ['해시태그1', '해시태그3']
post2.deleteTags(de1_tag2)
sess.commit()
# Out:
# 2023-09-08 07:19:44,652 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:44,652 INFO sqlalchemy.engine.Engine [cached since 3.631s ago] ('해시태그1',)
# 2023-09-08 07:19:44,654 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?
# 2023-09-08 07:19:44,656 INFO sqlalchemy.engine.Engine [cached since 3.577s ago] ('해시태그1',)
# 2023-09-08 07:19:44,657 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,659 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,660 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:44,661 INFO sqlalchemy.engine.Engine [cached since 3.624s ago] (1,)
# 2023-09-08 07:19:44,663 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,664 INFO sqlalchemy.engine.Engine [cached since 3.624s ago] (1,)
# 2023-09-08 07:19:44,666 INFO sqlalchemy.engine.Engine DELETE FROM "TAGS" WHERE "TAGS"."FK1" = ? AND "TAGS"."FK2" = ?
# 2023-09-08 07:19:44,666 INFO sqlalchemy.engine.Engine [generated in 0.00054s] (1, 1)
# 2023-09-08 07:19:44,667 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,668 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,669 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,670 INFO sqlalchemy.engine.Engine [cached since 3.63s ago] (1,)
# 2023-09-08 07:19:44,672 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,672 INFO sqlalchemy.engine.Engine [cached since 3.622s ago] (1, 1)
# 2023-09-08 07:19:44,673 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,675 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,676 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:44,677 INFO sqlalchemy.engine.Engine [cached since 3.655s ago] ('해시태그1',)
# 2023-09-08 07:19:44,679 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?
# 2023-09-08 07:19:44,680 INFO sqlalchemy.engine.Engine [cached since 3.601s ago] ('해시태그1',)
# 2023-09-08 07:19:44,681 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,683 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,685 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:44,686 INFO sqlalchemy.engine.Engine [cached since 3.664s ago] ('해시태그3',)
# 2023-09-08 07:19:44,688 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?
# 2023-09-08 07:19:44,689 INFO sqlalchemy.engine.Engine [cached since 3.61s ago] ('해시태그3',)
# 2023-09-08 07:19:44,690 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,691 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,693 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:44,694 INFO sqlalchemy.engine.Engine [cached since 3.657s ago] (2,)
# 2023-09-08 07:19:44,696 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,696 INFO sqlalchemy.engine.Engine [cached since 3.656s ago] (1,)
# 2023-09-08 07:19:44,700 INFO sqlalchemy.engine.Engine DELETE FROM "TAGS" WHERE "TAGS"."FK1" = ? AND "TAGS"."FK2" = ?
# 2023-09-08 07:19:44,703 INFO sqlalchemy.engine.Engine [cached since 0.03691s ago] (2, 1)
# 2023-09-08 07:19:44,704 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,707 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,708 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,709 INFO sqlalchemy.engine.Engine [cached since 3.669s ago] (1,)
# 2023-09-08 07:19:44,712 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,716 INFO sqlalchemy.engine.Engine [cached since 3.666s ago] (0, 1)
# 2023-09-08 07:19:44,719 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:44,720 INFO sqlalchemy.engine.Engine [cached since 3.683s ago] (2,)
# 2023-09-08 07:19:44,722 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,724 INFO sqlalchemy.engine.Engine [cached since 3.683s ago] (3,)
# 2023-09-08 07:19:44,727 INFO sqlalchemy.engine.Engine DELETE FROM "TAGS" WHERE "TAGS"."FK1" = ? AND "TAGS"."FK2" = ?
# 2023-09-08 07:19:44,728 INFO sqlalchemy.engine.Engine [cached since 0.06188s ago] (2, 3)
# 2023-09-08 07:19:44,730 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:44,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:44,733 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,735 INFO sqlalchemy.engine.Engine [cached since 3.695s ago] (3,)
# 2023-09-08 07:19:44,738 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:44,738 INFO sqlalchemy.engine.Engine [cached since 3.688s ago] (0, 3)
# 2023-09-08 07:19:44,740 INFO sqlalchemy.engine.Engine COMMIT

# %%
# 확인
sess.query(Hashtag).all()
"""
pk     hashtag    cnt
1     해시태그1     0
2     해시태그2     1
3     해시태그3     0
"""
# Out:
# 2023-09-08 07:19:47,132 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:47,133 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# 2023-09-08 07:19:47,133 INFO sqlalchemy.engine.Engine [cached since 4.075s ago] ()
# '\npk     hashtag    cnt\n1     해시태그1     0\n2     해시태그2     1\n3     해시태그3     0\n'

# %%
# 테그 수정 예시
bf_tag1 = ['해시태그2']
af_tag1 = ['해시태그4']

post1.modifiedTags(bf_tag1, af_tag1)
sess.commit()
# Out:
# 2023-09-08 07:19:51,908 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:51,909 INFO sqlalchemy.engine.Engine [cached since 10.89s ago] ('해시태그2',)
# 2023-09-08 07:19:51,911 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?
# 2023-09-08 07:19:51,913 INFO sqlalchemy.engine.Engine [cached since 10.83s ago] ('해시태그2',)
# 2023-09-08 07:19:51,914 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:51,915 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:51,916 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:51,917 INFO sqlalchemy.engine.Engine [cached since 10.88s ago] (1,)
# 2023-09-08 07:19:51,918 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,919 INFO sqlalchemy.engine.Engine [cached since 10.88s ago] (2,)
# 2023-09-08 07:19:51,920 INFO sqlalchemy.engine.Engine DELETE FROM "TAGS" WHERE "TAGS"."FK1" = ? AND "TAGS"."FK2" = ?
# 2023-09-08 07:19:51,921 INFO sqlalchemy.engine.Engine [cached since 7.255s ago] (1, 2)
# 2023-09-08 07:19:51,921 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:51,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:51,922 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,923 INFO sqlalchemy.engine.Engine [cached since 10.88s ago] (2,)
# 2023-09-08 07:19:51,924 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,925 INFO sqlalchemy.engine.Engine [cached since 10.88s ago] (0, 2)
# 2023-09-08 07:19:51,925 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."NAME" = ?) AS anon_1
# 2023-09-08 07:19:51,926 INFO sqlalchemy.engine.Engine [cached since 10.9s ago] ('해시태그4',)
# 2023-09-08 07:19:51,927 INFO sqlalchemy.engine.Engine INSERT INTO "HASHTAG" ("NAME") VALUES (?) RETURNING "PK", "CNT"
# 2023-09-08 07:19:51,928 INFO sqlalchemy.engine.Engine [cached since 10.9s ago] ('해시태그4',)
# 2023-09-08 07:19:51,928 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:51,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:51,930 INFO sqlalchemy.engine.Engine SELECT "POST"."PK" AS "POST_PK", "POST"."CONTENT" AS "POST_CONTENT"
# FROM "POST"
# WHERE "POST"."PK" = ?
# 2023-09-08 07:19:51,930 INFO sqlalchemy.engine.Engine [cached since 10.89s ago] (1,)
# 2023-09-08 07:19:51,931 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,932 INFO sqlalchemy.engine.Engine [cached since 10.89s ago] (4,)
# 2023-09-08 07:19:51,933 INFO sqlalchemy.engine.Engine INSERT INTO "TAGS" ("FK1", "FK2") VALUES (?, ?)
# 2023-09-08 07:19:51,933 INFO sqlalchemy.engine.Engine [cached since 10.89s ago] (1, 4)
# 2023-09-08 07:19:51,934 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-08 07:19:51,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:51,936 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,937 INFO sqlalchemy.engine.Engine [cached since 10.9s ago] (4,)
# 2023-09-08 07:19:51,939 INFO sqlalchemy.engine.Engine UPDATE "HASHTAG" SET "CNT"=? WHERE "HASHTAG"."PK" = ?
# 2023-09-08 07:19:51,939 INFO sqlalchemy.engine.Engine [cached since 10.89s ago] (1, 4)
# 2023-09-08 07:19:51,940 INFO sqlalchemy.engine.Engine COMMIT

# %%
# 확인
sess.query(Hashtag).all()

"""
pk     hashtag    cnt
1     해시태그1     0
2     해시태그2     0
3     해시태그3     0
4     해시태그4     1
"""
# Out:
# 2023-09-08 07:19:54,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-08 07:19:54,070 INFO sqlalchemy.engine.Engine SELECT "HASHTAG"."PK" AS "HASHTAG_PK", "HASHTAG"."NAME" AS "HASHTAG_NAME", "HASHTAG"."CNT" AS "HASHTAG_CNT"
# FROM "HASHTAG"
# 2023-09-08 07:19:54,071 INFO sqlalchemy.engine.Engine [cached since 11.01s ago] ()
# 2023-09-08 07:19:54,074 INFO sqlalchemy.engine.Engine SELECT "TAGS"."PK" AS "TAGS_PK", "TAGS"."FK1" AS "TAGS_FK1", "TAGS"."FK2" AS "TAGS_FK2"
# FROM "TAGS"
# WHERE ? = "TAGS"."FK2"
# 2023-09-08 07:19:54,075 INFO sqlalchemy.engine.Engine [generated in 0.00151s] (1,)
# 2023-09-08 07:19:54,076 INFO sqlalchemy.engine.Engine SELECT "TAGS"."PK" AS "TAGS_PK", "TAGS"."FK1" AS "TAGS_FK1", "TAGS"."FK2" AS "TAGS_FK2"
# FROM "TAGS"
# WHERE ? = "TAGS"."FK2"
# 2023-09-08 07:19:54,077 INFO sqlalchemy.engine.Engine [cached since 0.00401s ago] (2,)
# 2023-09-08 07:19:54,079 INFO sqlalchemy.engine.Engine SELECT "TAGS"."PK" AS "TAGS_PK", "TAGS"."FK1" AS "TAGS_FK1", "TAGS"."FK2" AS "TAGS_FK2"
# FROM "TAGS"
# WHERE ? = "TAGS"."FK2"
# 2023-09-08 07:19:54,079 INFO sqlalchemy.engine.Engine [cached since 0.006293s ago] (3,)
# 2023-09-08 07:19:54,079 INFO sqlalchemy.engine.Engine SELECT "TAGS"."PK" AS "TAGS_PK", "TAGS"."FK1" AS "TAGS_FK1", "TAGS"."FK2" AS "TAGS_FK2"
# FROM "TAGS"
# WHERE ? = "TAGS"."FK2"
# 2023-09-08 07:19:54,079 INFO sqlalchemy.engine.Engine [cached since 0.008146s ago] (4,)
# [1, 해시태그1, 0, 2, 해시태그2, 0, 3, 해시태그3, 0, 4, 해시태그4, 1]
